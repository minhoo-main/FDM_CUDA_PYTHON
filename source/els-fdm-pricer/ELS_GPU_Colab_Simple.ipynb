# %% [markdown]
# # 🚀 ELS GPU 테스트 - 간단 버전
#
# **파일 업로드 없이 바로 시작!**
#
# ---
#
# ## ⚡ 중요: GPU 활성화
#
# 1. `Runtime` → `Change runtime type`
# 2. Hardware accelerator: **GPU**
# 3. Save
#
# ---

# %% [markdown]
# ## 📦 Step 1: 프로젝트 코드 직접 생성

# %%
# 프로젝트 디렉토리 생성
# !mkdir -p els-fdm-pricer/src/{models,grid,solvers,pricing}

print("✓ 프로젝트 구조 생성 완료!")

# %%
# %%writefile els-fdm-pricer/src/__init__.py
"""ELS FDM Pricer Package"""
from .models.els_product import ELSProduct, create_sample_els
from .pricing.els_pricer import price_els

try:
    from .pricing.gpu_els_pricer import price_els_gpu
except ImportError:
    pass

# %%
# %%writefile els-fdm-pricer/requirements.txt
# numpy>=1.20.0
# scipy>=1.7.0

# %% [markdown]
# ### ELS 상품 모델

# %%
# %%writefile els-fdm-pricer/src/models/__init__.py
from .els_product import ELSProduct, create_sample_els

# %%
# %%writefile els-fdm-pricer/src/models/els_product.py
# Colab에서 GitHub raw URL로 파일 다운로드
import urllib.request
import sys

# 임시로 여기에 코드를 직접 작성
# 또는 GitHub에 업로드 후 다운로드

print("파일 생성 중...")

# %% [markdown]
# ## 🔄 더 나은 방법: GitHub에서 다운로드

# %%
# GitHub에 프로젝트를 올렸다면:
# !git clone https://github.com/your-username/els-fdm-pricer.git
# %cd els-fdm-pricer

print("GitHub 업로드 후 이 방법 사용 권장!")
